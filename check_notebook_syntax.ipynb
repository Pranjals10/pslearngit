# %% [markdown]
# # Notebook to test notebook syntax checks and PII detection
# This notebook contains a cell with a syntax error and a cell with PII (emails and phone numbers).

# %%
print('This is a valid cell')

# %%
for i in range(3)  # missing colon -> syntax error
    print(i)

# %%
# Cell containing PII examples
users = [
  {'name':'Alice', 'email':'alice.smith@example.com', 'phone': '+1-555-123-4567'},
  {'name':'Bob', 'email':'bob.jones@example.com', 'ssn':'123-45-6789'}
]
users
